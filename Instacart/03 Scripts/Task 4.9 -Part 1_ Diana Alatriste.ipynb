# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Dataframe 'customers.csv'

# %%
# Create path

path = r'/Users/dianaalatriste/Documents/Instacart'

# %%
# Import dataframe 'customers'

df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
# Check output

df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df.tail()
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 206204             1    married  148828
# 206205             3    married  168639
# 206206             2    married   53374
# 206207             1    married   99799
# 206208             1    married   57095

# %% [markdown]
# # 03. Cleaning dataframe by changing data types

# %%
# Check datatypes of columns

df.dtypes
# Out:
# user_id         object
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
df['user_id'] = df['user_id'].astype('str')

# %%
df['Age'] = df['Age'].astype('int8')

# %%
df['income'] = df['income'].astype('int32')

# %%
df['n_dependants'] = df['n_dependants'].astype('int8')

# %%
#Recheck data types

df.dtypes
# Out:
# user_id               object
# First Name            object
# Surname               object
# Gender                object
# State                 object
# Age                     int8
# number_of_children      int8
# fam_status            object
# income                 int32
# dtype: object

# %% [markdown]
# # 04. Wrangle data so that it follows consistent logic

# %% [markdown]
# ### First, I will rename the columns

# %%
# Renaming columns with illogical names - SURNAM to SURNAME

df.rename(columns = {'Surnam' : 'Surname'}, inplace = True)

# %%
# Rename column n_dependants to number_of_children

df.rename(columns = {'n_dependants' : 'number_of_children'}, inplace = True)

# %%
#Rename column STATE to State

df.rename(columns = {'STATE' : 'State'}, inplace = True)

# %%
# Check output

df.head()
# Out:
#   user_id First Name   Surname  Gender       State  Age  number_of_children  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48                   3
# 1   33890   Patricia      Hart  Female  New Mexico   36                   0
# 2   65803    Kenneth    Farley    Male       Idaho   35                   2
# 3  125935   Michelle     Hicks  Female        Iowa   40                   0
# 4  130797        Ann   Gilmore  Female    Maryland   26                   1
#
#   fam_status  income
# 0    married  165665
# 1     single   59285
# 2    married   99568
# 3     single   42049
# 4    married   40374

# %% [markdown]
# ### With columns renamed, now drop columns that are not relevant for analysis

# %%
df = df.drop(columns = ['date_joined'])

# %%
# Check shape

df.shape
# Out:
# (206209, 9)

# %% [markdown]
# # 05. Fundamental data quality and consistency checks

# %% [markdown]
# ## Missing values

# %%
# Finding missing values

df.isnull().sum()
# Out:
# user_id                   0
# First Name            11259
# Surname                   0
# Gender                    0
# State                     0
# Age                       0
# number_of_children        0
# fam_status                0
# income                    0
# dtype: int64

# %% [markdown]
# #### First name column has a total of 11259 values

# %%
# Analyzing the missing values further

df_nan = df[df['First Name'].isnull() == True]

# %%
# Calling df_nan

df_nan
# Out:
#        user_id First Name   Surname  Gender         State  Age  \
# 53       76659        NaN   Gilbert    Male      Colorado   26
# 73       13738        NaN     Frost  Female     Louisiana   39
# 82       89996        NaN    Dawson  Female        Oregon   52
# 99       96166        NaN   Oconnor    Male      Oklahoma   51
# 105      29778        NaN    Dawson  Female          Utah   63
# ...        ...        ...       ...     ...           ...  ...
# 206038  121317        NaN    Melton    Male  Pennsylvania   28
# 206044  200799        NaN  Copeland  Female        Hawaii   52
# 206090  167394        NaN     Frost  Female        Hawaii   61
# 206162  187532        NaN     Floyd  Female    California   39
# 206171  116898        NaN   Delgado  Female      Colorado   23
#
#         number_of_children fam_status  income
# 53                       2    married   41709
# 73                       0     single   82518
# 82                       3    married  117099
# 99                       1    married  155673
# 105                      3    married  151819
# ...                    ...        ...     ...
# 206038                   3    married   87783
# 206044                   2    married  108488
# 206090                   1    married   45275
# 206162                   0     single   56325
# 206171                   2    married   59222
#
# [11259 rows x 9 columns]

# %% [markdown]
# #### Missing values do not interfere with analysis so they won't be removed, nor imputed.

# %% [markdown]
# ## Mixed-Type Data

# %%
# Check for mixed-type data in dataframe 'df'

for col in df.columns.tolist():
    weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df[weird]) > 0:
        print(col)
# Out:
# First Name

# %% [markdown]
# #### Column 'First Name' has mixed-type data

# %%
# Change data type of 'First Name'

df['First Name'] = df['First Name'].astype('str')

# %%
# Change null values no 'NA' in 'First Name' column

df['First Name'].fillna('NA', inplace=True)

# %%
# Check output

df.tail(40)
# Out:
#        user_id   First Name     Surname  Gender           State  Age  \
# 206169   99254         Lori       Watts  Female        Delaware   75
# 206170  114593  Christopher   Velazquez    Male        Virginia   34
# 206171  116898           NA     Delgado  Female        Colorado   23
# 206172  120440       Philip       Duran    Male    North Dakota   42
# 206173  122524      Phyllis      Greene    Male        Nebraska   77
# 206174  134553        Ralph      Avalos    Male         Indiana   25
# 206175  167749      Deborah     Farrell  Female         Florida   28
# 206176  186595         Ruth  Cunningham  Female     Mississippi   38
# 206177  199732    Katherine      Abbott  Female            Iowa   71
# 206178  138442       Gloria    Cantrell  Female  North Carolina   26
# 206179  177599        Donna        Ruiz  Female          Kansas   71
# 206180   48091       Jeremy      Willis    Male   West Virginia   37
# 206181  192077        Susan        Nash  Female         Georgia   54
# 206182  180181         Carl     Bridges    Male   West Virginia   77
# 206183   79560       Steven      Sutton    Male         Wyoming   78
# 206184   61944       Walter        Park    Male            Ohio   54
# 206185  149397         Tina          Wu  Female        Kentucky   22
# 206186  107955       Victor      Guzman    Male    Pennsylvania   41
# 206187  163443          Roy      Harvey    Male    Pennsylvania   37
# 206188   93669     Patricia        Cole  Female        Maryland   74
# 206189  193828      Russell      Travis    Male  North Carolina   46
# 206190  197067        Kathy        Bell  Female         Arizona   42
# 206191    7177      Russell   Zimmerman    Male     Mississippi   71
# 206192   61888       Joshua      Guerra    Male      New Jersey   37
# 206193  103412       Willie     Goodman    Male        Michigan   46
# 206194  189337        Shawn        Wood    Male      New Jersey   56
# 206195  205766       Amanda       Hodge  Female          Oregon   18
# 206196  139950       Gloria      Murray  Female        Colorado   45
# 206197   74598  Christopher   Velazquez    Male       Minnesota   52
# 206198   83573       Gloria      Murray  Female        Michigan   28
# 206199  179673         Adam  Villanueva    Male         Wyoming   77
# 206200  192637        Kelly    Petersen  Female         Florida   47
# 206201   75529        Kathy       Avila  Female   West Virginia   25
# 206202  157533          Ned       Stark    Male            Utah   53
# 206203  122741         Carl       Weber    Male        Michigan   24
# 206204  168073         Lisa        Case  Female  North Carolina   44
# 206205   49635       Jeremy     Robbins    Male          Hawaii   62
# 206206  135902        Doris    Richmond  Female        Missouri   66
# 206207   81095         Rose     Rollins  Female      California   27
# 206208   80148      Cynthia       Noble  Female        New York   55
#
#         number_of_children                        fam_status  income
# 206169                   1                           married  156966
# 206170                   2                           married   75707
# 206171                   2                           married   59222
# 206172                   3                           married  120080
# 206173                   0                  divorced/widowed  163113
# 206174                   1                           married   64482
# 206175                   1                           married   30169
# 206176                   1                           married   92727
# 206177                   1                           married   31019
# 206178                   1                           married   46199
# 206179                   3                           married  119306
# 206180                   3                           married   31048
# 206181                   3                           married  160664
# 206182                   2                           married  167232
# 206183                   3                           married  101764
# 206184                   0                            single   58050
# 206185                   1                           married   32242
# 206186                   3                           married  136624
# 206187                   0                            single   82652
# 206188                   1                           married  122136
# 206189                   1                           married  160483
# 206190                   0                            single  114821
# 206191                   3                           married   64400
# 206192                   1                           married   68491
# 206193                   2                           married  154481
# 206194                   1                           married   40373
# 206195                   2  living with parents and siblings   48510
# 206196                   2                           married  150954
# 206197                   0                            single  140700
# 206198                   0                            single   32237
# 206199                   0                  divorced/widowed  162239
# 206200                   0                            single   50638
# 206201                   2                           married   56513
# 206202                   0                            single   35973
# 206203                   2                           married   73357
# 206204                   1                           married  148828
# 206205                   3                           married  168639
# 206206                   2                           married   53374
# 206207                   1                           married   99799
# 206208                   1                           married   57095

# %%
# Re check for mixed-type data in dataframe 'df'

for col in df.columns.tolist():
    weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df[weird]) > 0:
        print(col)
print(c)
# Out:
# The code has been run

# %% [markdown]
# #### Data-mixed type has been addressed and solved by changing all null values to 'NA's in the 'First Name' column

# %% [markdown]
# ## Duplicates

# %%
# Finding duplicates

df_dups = df[df.duplicated()]
print('The code has been run')
# Out:
# The code has been run

# %% [markdown]
# #### No duplicates were identified

# %% [markdown]
# # 06. Combine customer data with rest of prepared Instacart data

# %%
# Import 'orders_products_merged_updated3.pkl'

df_ordsprods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated3.pkl'))

# %%
# Check shape of output

df_ordsprods_merged.shape
# Out:
# (32404859, 22)

# %%
df_ordsprods_merged.dtypes
# Out:
# order_id                   int64
# user_id                   object
# order_number                int8
# orders_day_of_week          int8
# order_hour_of_day           int8
# last_purchase            float16
# product_id                 int32
# add_to_cart_order          int64
# reordered                   int8
# product_name              object
# department_id               int8
# prices                   float32
# price_range_loc           object
# busiest_day               object
# busiest_days              object
# busiest_period_of_day     object
# max_order                   int8
# loyalty_flag              object
# average_expenses         float64
# spending_flag             object
# user_behaviour           float16
# order_frequency_flag      object
# dtype: object

# %%
# Change data type of 'user_id' on df_ordsprods_merged

df_ordsprods_merged['user_id'] = df_ordsprods_merged['user_id'].astype('str')

# %%
# Re check data types of 'user_id' on df_ordsprods_merged

df_ordsprods_merged.dtypes
# Out:
# order_id                   int64
# user_id                   object
# order_number                int8
# orders_day_of_week          int8
# order_hour_of_day           int8
# last_purchase            float16
# product_id                 int32
# add_to_cart_order          int64
# reordered                   int8
# product_name              object
# department_id               int8
# prices                   float32
# price_range_loc           object
# busiest_day               object
# busiest_days              object
# busiest_period_of_day     object
# max_order                   int8
# loyalty_flag              object
# average_expenses         float64
# spending_flag             object
# user_behaviour           float16
# order_frequency_flag      object
# dtype: object

# %%
# Combine dataframes

df_all = df_ordsprods_merged.merge(df, on = 'user_id', indicator = True)

# %%
# Check output

df_all.head()
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
#
#    last_purchase  product_id  add_to_cart_order  reordered product_name  ...  \
# 0            NaN         196                  1          0         Soda  ...
# 1           15.0         196                  1          1         Soda  ...
# 2           21.0         196                  1          1         Soda  ...
# 3           29.0         196                  1          1         Soda  ...
# 4           28.0         196                  1          1         Soda  ...
#
#     order_frequency_flag  First Name Surname  Gender    State Age  \
# 0  Non-frequent customer       Linda  Nguyen  Female  Alabama  31
# 1  Non-frequent customer       Linda  Nguyen  Female  Alabama  31
# 2  Non-frequent customer       Linda  Nguyen  Female  Alabama  31
# 3  Non-frequent customer       Linda  Nguyen  Female  Alabama  31
# 4  Non-frequent customer       Linda  Nguyen  Female  Alabama  31
#
#    number_of_children fam_status  income _merge
# 0                   3    married   40423   both
# 1                   3    married   40423   both
# 2                   3    married   40423   both
# 3                   3    married   40423   both
# 4                   3    married   40423   both
#
# [5 rows x 31 columns]

# %%
# Check output

df_all.shape
# Out:
# (32404859, 31)

# %%
# Summing up values on '_merge' column

df_all['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # 07. Export newly merged dataframe

# %%
df_all.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merged.pkl'))

# %%
print('End of Part 1')
# Out:
# End of Part 1
